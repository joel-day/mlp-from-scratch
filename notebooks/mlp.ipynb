# %% [markdown]
# # MLP from scratch w/ Numpy (Health_Score)

# %% [markdown]
# ![neural network_4.png](data:image/png;base64,...)

# %%
from packages.mlp.train_model import mlp_health_score

# %%
# predict health values based on theee custom metrics
age = 20
health = 1
diet = 5

# %%
health_score = mlp_health_score(age, health, diet)
print(health_score)
# Out:
# Training Time:  1.444 Seconds
# 4.961286119115041
